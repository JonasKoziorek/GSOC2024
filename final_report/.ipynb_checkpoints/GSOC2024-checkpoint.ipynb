# %% [markdown]
# # GSOC 2024
# ## Jonas Koziorek
#
# * **Organization**: The Julia Language (https://julialang.org/)
# * **Mentor**: George Datseris (https://github.com/Datseris)
#
# # Project Goals
#
# The primary objective of this project was to develop a unified interface for periodic orbit detection algorithms. These algorithms are essential tools in the study of dynamical systems, particularly for identifying recurring trajectories in systems that exhibit complex or chaotic behavior. While several algorithms already existed in Julia packages such as DynamicalSystems.jl and BifurcationKit.jl, they lacked a cohesive structure and synchronization. My task involved not only unifying these algorithms under a common interface but also implementing new ones based on recent advancements in the field.
# Additionally, the project aimed to bridge the gap between DynamicalSystems.jl and BifurcationKit.jl, offering users a more unified experience.
#
# # My contribution
#
# In the beginning we decided that all the new code should go into a new Julia package [**PeriodicOrbits.jl**](https://github.com/JuliaDynamics/PeriodicOrbits.jl) which falls under the [**JuliaDynamics** ecosystem](https://github.com/JuliaDynamics). In the first half of the program I devised a public interface which all the detection algorithms should follow. In the second half I focused on developing new detection algorithms and writing documentation.
#
# ## Public Interface
#
# The public interface encompasses these features:
#
# 1. Custom type for periodic orbits
# 2. Custom type for initial guesses which are required in the detection algorithms
# 3. Abstract supertype for all the detection algorithms
# 4. Function which computes minimal period of the periodic orbit
# 5. Function that evaluates local stability properties of the periodic orbit
# 6. Function that computes distance between two periodic orbits
# 7. Function that finds unique periodic orbits in a list of periodic orbits
#
# All the features work for both discrete-time and continuous-time dynamical systems.
#
# ## Implemented Algorithms
#
# For discrete-time dynamical systems there are two options - Schmelcher & Diakonos algorithm or Davidchack & Lai algorithm.
# For continuous-time dynamical systems there are two options - Optimized Shooting algorithm or discrete-time algorithms in combination with Poincaré map.
#
# ## My Pull Requests
#
# 1. [PR #2](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/2)
# 2. [PR #3](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/3)
# 3. [PR #5](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/5)
# 4. [PR #6](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/6)
# 5. [PR #7](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/7)
# 6. [PR #15](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/15)
# 7. [PR #16](https://github.com/JuliaDynamics/PeriodicOrbits.jl/pull/16)
# 8. [PR #211](https://github.com/JuliaDynamics/DynamicalSystemsBase.jl/pull/211)
#
#
# # Current State
#
# The public interface has been successfully completed. Two detection algorithms from ChaosTools.jl were ported to PeriodicOrbits.jl, and a new detection algorithm specifically designed for continuous-time dynamical systems was added. All the current work is fully supported with tests and documentation.
#
# # What is left to do
#
# **Integration with BifurcationKit.jl**: Strengthening the connection between PeriodicOrbits.jl and BifurcationKit.jl would significantly improve the flexibility and applicability of the package. However, the maintainers of BifurcationKit.jl have not yet contributed to PeriodicOrbits.jl, and full integration between the two remains an open task. While this integration was not the primary focus of my GSOC project, it presents a valuable opportunity for future development and collaboration.
#
# **Further Algorithm Development**: While the current selection of detection algorithms is functional, there is potential to incorporate more sophisticated methods. For instance, I started implementing the [**Fictitious time integration method**](https://www.sciencedirect.com/science/article/pii/S0020746223000409) but could not complete it within the program's timeframe. Continuing this work would broaden the range of tools available to users.
#
#
# # Challenges
#
# A big hurdle in the beginning was to learn the mathematical foundation needed to read papers about detection algorithms. Even though there are periodic orbit detection algorithms inside BifurcationKit.jl, it was a challenge to understand how they work and whether they would fit into the new interface.
#
# Furthermore, two algorithms I tried to implement turned out to be unsuitable:
#
# 1. [**Numerical detection of unstable periodic orbits in continuous-time dynamical systems with chaotic behaviors**](https://npg.copernicus.org/articles/14/615/2007/) - I implemented this algorithm but I couldn't make it work correctly. After some time I dropped my efforts.
# 2. [**Determination of Unstable Limit Cycles in Chaotic Systems by the Method of Unrestricted Harmonic Balance**](https://www.degruyter.com/document/doi/10.1515/zna-1991-0605/html) - This method required extensive manual intervention, making it impractical for automation in a general-use package.
#
# In addition to the technical challenges, I faced difficulties with time management and self-discipline. Working in a fully remote setting with the freedom to set my own schedule often led to procrastination and periods of low motivation. I hadn’t anticipated how significant this challenge would be, and it required me to develop strategies for staying focused and maintaining a consistent work routine.
#
# # What I learned
#
# Throughout this project, I gained substantial experience in working with GitHub and the open-source development process, particularly how to structure contributions, manage pull requests, and use CI for automated testing and documentation deployment. I deepened my understanding of numerical methods in dynamical systems and became more familiar with the JuliaDynamics ecosystem. Working through scientific papers and translating algorithms into practical code sharpened both my research and implementation skills.

# %% [markdown]
# # Code Showcase
#
# The unified interface allows the user to use the same functions for both discrete-time and continuous-time dynamical systems. The detection algorithms can be called via two options: `periodic_orbit(dynamical_system, algorithm, initial_guess)` or `periodic_orbits(dynamical_system, algorithm, initial_guesses)`.
#
# Let's attempt to detect a periodic orbit of the Lorenz system, eg. continuous-time dynamical system. First, we define the Lorenz system itself.

# %%
import Pkg
Pkg.add(url="https://github.com/JuliaDynamics/PeriodicOrbits.jl")
# Out:
#     Updating git-repo `https://github.com/JuliaDynamics/PeriodicOrbits.jl`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.10/Project.toml`
#   No Changes to `~/.julia/environments/v1.10/Manifest.toml`

# %%
using PeriodicOrbits
using DynamicalSystemsBase

function lorenz(u0=[0.0, 10.0, 0.0]; σ = 10.0, ρ = 28.0, β = 8/3)
    return CoupledODEs(lorenz_rule, u0, [σ, ρ, β])
end

@inbounds function lorenz_rule(u, p, t)
    du1 = p[1] * (u[2] - u[1])
    du2 = u[1] * (p[2] - u[3]) - u[2]
    du3 = u[1] * u[2] - p[3] * u[3]
    return SVector{3}(du1, du2, du3)
end

ds = lorenz()
# Out:
# 3-dimensional CoupledODEs
#  deterministic: true
#  discrete time: false
#  in-place:      false
#  dynamic rule:  lorenz_rule
#  ODE solver:    Tsit5
#  ODE kwargs:    (abstol = 1.0e-6, reltol = 1.0e-6)
#  parameters:    [10.0, 28.0, 2.6666666666666665]
#  time:          0.0
#  state:         [0.0, 10.0, 0.0]

# %% [markdown]
# Next, we give an initial guess of the location of the periodic orbit and its period.

# %%
u0_guess = SVector(3.5, 3.0, 0.0)
T_guess = 5.2
ig = InitialGuess(u0_guess, T_guess)
# Out:
# InitialGuess{SVector{3, Float64}, Float64}([3.5, 3.0, 0.0], 5.2)

# %% [markdown]
# Then, we pick an appropriate algorithm that will detect the periodic orbit. In this case, we can use any algorithm intended for continuous-time dynamical systems. We choose the Optimized Shooting algorithm.

# %%
alg = OptimizedShooting(Δt = 0.01, n = 3)
# Out:
# OptimizedShooting{@NamedTuple{reltol::Float64, abstol::Float64, maxiters::Int64}}(0.01, 3, (reltol = 1.0e-6, abstol = 1.0e-6, maxiters = 1000))

# %% [markdown]
# Finally, we combine all the pieces to find the periodic orbit.

# %%
po = periodic_orbit(ds, alg, ig)
po
# Out:
# PeriodicOrbit{3, Float64, Float64}
#  u0:       [-0.75151, -1.46495, 6.90937]
#  T:        5.78341
#  stable:   nothing
#  discrete: false
#  length:   57

# %% [markdown]
# To ensure that the detected period of the periodic orbit is minimal, i.e., it is not a multiple of the minimal period, we can use the minimal_period function.

# %%
minT_po = minimal_period(ds, po)
minT_po
# Out:
# PeriodicOrbit{3, Float64, Float64}
#  u0:       [-0.75151, -1.46495, 6.90937]
#  T:        5.78341
#  stable:   nothing
#  discrete: false
#  length:   100

# %% [markdown]
# To check whether two periodic orbits are equivalent up to some tolerance, use the poequal function.

# %%
equal = poequal(po, minT_po; dthres = 1e-3, Tthres = 1e-3)
"Detected periodic orbit had minimal period: $(equal)"
# Out:
# "Detected periodic orbit had minimal period: true"

# %% [markdown]
# To determine whether the found periodic orbit is stable or unstable, we can apply the isstable function.

# %%
po = isstable(ds, po)
"Detected periodic orbit is $(po.stable ? "stable" : "unstable")."
# Out:
# "Detected periodic orbit is unstable."

# %% [markdown]
# The closed curve of the periodic orbit can be visualized using a plotting library such as CairoMakie.jl.

# %%
using CairoMakie

u0 = po.points[1]
T = po.T
traj, t = trajectory(ds, T, u0; Dt = 0.01)

fig = Figure()
ax = Axis3(fig[1, 1], azimuth = 0.6pi, elevation = 0.1pi, title="$(po.stable ? "Stable" : "Unstable") periodic orbit of lorenz system")
lines!(ax, vec(traj), color = :blue, linewidth = 1.7)
scatter!(ax, vec(po.points), color=:blue)
fig

# %% [markdown]
# Let's us now try to find periodic orbits of discrete-time dynamical system instead.

# %%
function henon(u0=zeros(2); a = 1.4, b = 0.3)
    return DeterministicIteratedMap(henon_rule, u0, [a,b])
end
henon_rule(x, p, n) = SVector{2}(1.0 - p[1]*x[1]^2 + x[2], p[2]*x[1])
xs = LinRange(-3.0, 3.0, 10)
ys = LinRange(-10.0, 10.0, 10)

ds = henon()
λs = [0.01, 0.1, 0.5]
indss, signss = lambdaperms(dimension(ds))
period = 8
alg = SchmelcherDiakonos(o=period, λs=λs, indss=indss, signss=signss)
igs = InitialGuess[InitialGuess(SVector(x, y), nothing) for x in xs for y in ys]
pos = periodic_orbits(ds, alg, igs)
# Out:
# 18-element Vector{PeriodicOrbit}:
#  PeriodicOrbit{2, Float64, Int64}([-0.7169430866976617, 0.32072215435479856], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.5231000016287598, 0.32139571663073885], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6757773179366297, 0.1672557096065677], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6011118052773521, -0.21508293346145357], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.327669441611804, -0.14510658324941456], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6757773264803499, 0.167255727384494], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.8087672080728037, 0.3298359508623914], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.8274542245093841, -0.3764638979749465], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.9758000465573256, -0.14274002659736673], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.7495715119047712, 0.15519339583231456], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6313544798516744, 0.18940634850614804], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([1.06907381662046, -0.11685672648295044], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([1.0690738166135614, -0.11685672650360777], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.8368082685514221, 0.3501334035584965], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.48368863924634975, -0.34479398654518184], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.7067667792704121, 0.33752098489582155], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6381939926170691, -0.21203003321458871], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.8371416822843252, -0.3776173533578846], 8, nothing)

# %% [markdown]
# The `SchmelcherDiakonos` algorithm detected some duplicate periodic orbits. To select only unique POs, we can use `uniquepos` function.

# %%
pos = uniquepos(pos)
# Out:
# 9-element Vector{PeriodicOrbit{2, Float64, Int64}}:
#  PeriodicOrbit{2, Float64, Int64}([-0.8371416822843252, -0.3776173533578846], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6381939926170691, -0.21203003321458871], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.48368863924634975, -0.34479398654518184], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.8368082685514221, 0.3501334035584965], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([1.0690738166135614, -0.11685672650360777], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.6313544798516744, 0.18940634850614804], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.7495715119047712, 0.15519339583231456], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([0.9758000465573256, -0.14274002659736673], 8, nothing)
#  PeriodicOrbit{2, Float64, Int64}([-0.8274542245093841, -0.3764638979749465], 8, nothing)

# %% [markdown]
# The `SchmelcherDiakonos` algorithm didn't report local stability of the given orbits. Let's determine it using `isstable`.

# %%
pos = [isstable(ds, po) for po in pos] # we can see that all the periodic orbits are unstable
# Out:
# 9-element Vector{PeriodicOrbit{2, Float64, Int64}}:
#  PeriodicOrbit{2, Float64, Int64}([-0.8371416822843252, -0.3776173533578846], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([0.6381939926170691, -0.21203003321458871], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([-0.48368863924634975, -0.34479398654518184], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([-0.8368082685514221, 0.3501334035584965], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([1.0690738166135614, -0.11685672650360777], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([0.6313544798516744, 0.18940634850614804], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([0.7495715119047712, 0.15519339583231456], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([0.9758000465573256, -0.14274002659736673], 8, false)
#  PeriodicOrbit{2, Float64, Int64}([-0.8274542245093841, -0.3764638979749465], 8, false)

# %% [markdown]
# Finally, let's visualize the chaotic attractor of Henon map (blue points) and the unstable periodic orbits (red points).

# %%
using CairoMakie

fig = Figure()
ax = Axis(fig[1, 1], title="Periodic orbits of henon map of period $(period)")

traj, t = trajectory(ds, 200, SVector(0.0, 0.0))
scatter!(ax, vec(traj), color = :blue, markersize=6.0)

for po in pos
    scatter!(ax, vec(po.points), color=:red, markersize=10.0)
end

fig

# %% [markdown]
# # Acknowledgements
#
# I would like to thank my mentor George Datseris who has been incredibly supportive over the course of the program. Furthermore, I want to thank to The Julia Language organization and GSOC program team who made this opportunity possible.
#
# # Conclusion
#
# This project successfully achieved its initial goal of creating a unified interface for periodic orbit detection algorithms. While there is still work to be done in terms of integrating more libraries and adding new algorithms, the foundation is solid, and the package is ready for further development and community contributions.
